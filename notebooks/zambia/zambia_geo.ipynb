# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import statsmodels.api as sm
from WBUtiles.WBClean import clean_wb_wide
from WBUtiles.WBSummary import summary_wb, plot_missing_heatmap
from WBUtiles.WBLatex import make_lookup_latex, make_summary_latex

sns.set_theme(
    style="whitegrid",     # clean academic look
    context="paper",       # scales text for papers
    font_scale=1.1
)

# %% [markdown]
# # Data Cleaning

# %%
geo = pd.read_csv('../../data/Zambia_Geographic/geo_natural_resource.csv')

# %%
geo_clean, geo_lookup = clean_wb_wide(geo, drop_top_rows=0)

# %%
print(
    make_lookup_latex(
        geo_lookup,
        caption='World Bank indicators used in Geographic and Natural Resource Analysis',
        label='tab:geo_indicator_list'
    )
)
# Out:
# \begin{table}
# \caption{World Bank indicators used in Geographic and Natural Resource Analysis}
# \label{tab:geo_indicator_list}
# \begin{tabular}{lp{10cm}}
# \toprule
# Series Code & Series Name \\
# \midrule
# AG.LND.IRIG.AG.ZS & Agricultural irrigated land (\% of total agricultural land) \\
# AG.LND.AGRI.ZS & Agricultural land (\% of land area) \\
# ER.H2O.FWTL.ZS & Annual freshwater withdrawals, total (\% of internal resources) \\
# AG.LND.ARBL.ZS & Arable land (\% of land area) \\
# NY.GDP.COAL.RT.ZS & Coal rents (\% of GDP) \\
# EN.CLC.MDAT.ZS & Droughts, floods, extreme temperatures (\% of population, average 1990-2009) \\
# AG.LND.FRST.ZS & Forest area (\% of land area) \\
# NY.GDP.FRST.RT.ZS & Forest rents (\% of GDP) \\
# VC.IDP.NWDS & Internally displaced persons, new displacement associated with disasters (number of cases) \\
# ER.H2O.FWST.ZS & Level of water stress: freshwater withdrawal as a proportion of available freshwater resources \\
# NY.GDP.MINR.RT.ZS & Mineral rents (\% of GDP) \\
# NY.GDP.NGAS.RT.ZS & Natural gas rents (\% of GDP) \\
# NY.GDP.PETR.RT.ZS & Oil rents (\% of GDP) \\
# ER.H2O.INTR.PC & Renewable internal freshwater resources per capita (cubic meters) \\
# ER.H2O.INTR.K3 & Renewable internal freshwater resources, total (billion cubic meters) \\
# NY.GDP.TOTL.RT.ZS & Total natural resources rents (\% of GDP) \\
# ER.GDP.FWTL.M3.KD & Water productivity, total (constant 2015 US\$ GDP per cubic meter of total freshwater withdrawal) \\
# \bottomrule
# \end{tabular}
# \end{table}

# %%
# Observed Seasonal Cycle
OSC_1901_1930 = pd.read_csv('../../data/Zambia_Geographic/Observed Seasonal Cycle_1901-1930.csv')
OSC_1931_1960 = pd.read_csv('../../data/Zambia_Geographic/Observed Seasonal Cycle_1931-1960.csv')
OSC_1961_1990 = pd.read_csv('../../data/Zambia_Geographic/Observed Seasonal Cycle_1961-1990.csv')
OSC_1991_2020 = pd.read_csv('../../data/Zambia_Geographic/Observed Seasonal Cycle_1991-2020.csv')

# %% [markdown]
# Each oberserved seasonal cycle contains 30 years average of monthly temperature and rainfall data.

# %%
def clean_osc(df, period):
    df = df.copy()

    # Rename columns (short + consistent)
    df = df.rename(columns={
        'Category': 'Month',
        'Average Minimum Surface Air Temperature (°C)': 'tasmin',
        'Average Mean Surface Air Temperature (°C)': 'tas',
        'Average Maximum Surface Air Temperature (°C)': 'tasmax',
        'Precipitation (mm)': 'pr'
    })

    # Add period label
    df['Period'] = period

    return df

# %%
osc1 = clean_osc(OSC_1901_1930, '1901-1930')
osc2 = clean_osc(OSC_1931_1960, '1931-1960')
osc3 = clean_osc(OSC_1961_1990, '1961-1990')
osc4 = clean_osc(OSC_1991_2020, '1991-2020')
osc_all = pd.concat([osc1, osc2, osc3, osc4], ignore_index=True)

# %%
osc_all
# Out:
#    Month  tasmin    tas  tasmax      pr     Period
# 0    Jan   17.87  22.97   28.13  225.03  1901-1930
# 1    Feb   17.74  22.97   28.25  205.38  1901-1930
# 2    Mar   17.28  22.79   28.36  165.64  1901-1930
# 3    Apr   15.46  21.88   28.35   38.98  1901-1930
# 4    May   11.88  19.51   27.20    6.05  1901-1930
# 5    Jun    9.14  17.50   25.91    0.40  1901-1930
# 6    Jul    8.39  16.92   25.50    0.10  1901-1930
# 7    Aug   10.61  19.16   27.76    0.14  1901-1930
# 8    Sep   14.27  22.66   31.10    2.47  1901-1930
# 9    Oct   17.27  24.82   32.42   22.82  1901-1930
# 10   Nov   18.02  24.44   30.90  100.51  1901-1930
# 11   Dec   18.02  23.33   28.68  209.51  1901-1930
# 12   Jan   17.97  22.91   27.91  235.98  1931-1960
# 13   Feb   18.01  22.96   27.96  216.55  1931-1960
# 14   Mar   17.45  22.83   28.25  164.82  1931-1960
# 15   Apr   15.71  22.02   28.37   40.70  1931-1960
# 16   May   12.28  19.72   27.21    5.56  1931-1960
# 17   Jun    9.41  17.35   25.33    0.53  1931-1960
# 18   Jul    8.78  17.10   25.46    0.08  1931-1960
# 19   Aug   10.92  19.32   27.77    0.22  1931-1960
# 20   Sep   14.50  22.69   30.92    1.96  1931-1960
# 21   Oct   17.43  24.95   32.53   22.80  1931-1960
# 22   Nov   18.06  24.25   30.50  112.13  1931-1960
# 23   Dec   17.95  23.13   28.37  218.71  1931-1960
# 24   Jan   17.76  22.83   27.96  231.36  1961-1990
# 25   Feb   17.75  22.89   28.09  205.61  1961-1990
# 26   Mar   17.29  22.84   28.44  159.83  1961-1990
# 27   Apr   15.45  21.86   28.32   49.95  1961-1990
# 28   May   11.86  19.53   27.25    6.09  1961-1990
# 29   Jun    8.93  17.31   25.74    0.59  1961-1990
# 30   Jul    8.46  17.07   25.72    0.13  1961-1990
# 31   Aug   10.82  19.43   28.08    0.26  1961-1990
# 32   Sep   14.44  22.85   31.32    3.03  1961-1990
# 33   Oct   17.12  24.66   32.26   28.20  1961-1990
# 34   Nov   17.90  24.19   30.53  112.02  1961-1990
# 35   Dec   17.87  23.08   28.34  223.42  1961-1990
# 36   Jan   18.20  23.33   28.50  235.23  1991-2020
# 37   Feb   18.22  23.50   28.83  197.02  1991-2020
# 38   Mar   17.82  23.40   29.02  161.99  1991-2020
# 39   Apr   15.75  22.26   28.81   42.84  1991-2020
# 40   May   12.44  20.23   28.08    5.72  1991-2020
# 41   Jun    9.68  18.12   26.62    0.49  1991-2020
# 42   Jul    9.12  17.66   26.25    0.18  1991-2020
# 43   Aug   11.56  20.16   28.82    0.26  1991-2020
# 44   Sep   14.97  23.43   31.94    2.64  1991-2020
# 45   Oct   17.70  25.35   33.05   23.11  1991-2020
# 46   Nov   18.61  25.01   31.46  109.86  1991-2020
# 47   Dec   18.40  23.78   29.22  207.92  1991-2020

# %% [markdown]
# # Check data availability

# %%
geo_summary = summary_wb(geo_clean, geo_lookup)
geo_summary
# Out:
#           Series Code                                        Series Name  \
# 0   AG.LND.IRIG.AG.ZS  Agricultural irrigated land (% of total agricu...
# 1      AG.LND.AGRI.ZS                 Agricultural land (% of land area)
# 2      ER.H2O.FWTL.ZS  Annual freshwater withdrawals, total (% of int...
# 3      AG.LND.ARBL.ZS                       Arable land (% of land area)
# 4   NY.GDP.COAL.RT.ZS                              Coal rents (% of GDP)
# 5      EN.CLC.MDAT.ZS  Droughts, floods, extreme temperatures (% of p...
# 6      AG.LND.FRST.ZS                       Forest area (% of land area)
# 7   NY.GDP.FRST.RT.ZS                            Forest rents (% of GDP)
# 8         VC.IDP.NWDS  Internally displaced persons, new displacement...
# 9      ER.H2O.FWST.ZS  Level of water stress: freshwater withdrawal a...
# 10  NY.GDP.MINR.RT.ZS                           Mineral rents (% of GDP)
# 11  NY.GDP.NGAS.RT.ZS                       Natural gas rents (% of GDP)
# 12  NY.GDP.PETR.RT.ZS                               Oil rents (% of GDP)
# 13     ER.H2O.INTR.PC  Renewable internal freshwater resources per ca...
# 14     ER.H2O.INTR.K3  Renewable internal freshwater resources, total...
# 15  NY.GDP.TOTL.RT.ZS           Total natural resources rents (% of GDP)
# 16  ER.GDP.FWTL.M3.KD  Water productivity, total (constant 2015 US$ G...
#
#     missing_pct  n_obs  first_year  last_year
# 0    100.000000      0         NaN        NaN
# 1      3.076923     63      1961.0     2023.0
# 2     52.307692     31      1992.0     2022.0
# 3      3.076923     63      1961.0     2023.0
# 4     21.538462     51      1971.0     2021.0
# 5     98.461538      1      2009.0     2009.0
# 6     47.692308     34      1990.0     2023.0
# 7     20.000000     52      1970.0     2021.0
# 8     80.000000     13      2008.0     2023.0
# 9     52.307692     31      1992.0     2022.0
# 10    20.000000     52      1970.0     2021.0
# 11    21.538462     51      1971.0     2021.0
# 12    21.538462     51      1971.0     2021.0
# 13     4.615385     62      1961.0     2022.0
# 14     4.615385     62      1961.0     2022.0
# 15    20.000000     52      1970.0     2021.0
# 16    52.307692     31      1992.0     2022.0

# %%
print(
    make_summary_latex(
    geo_summary,
    caption='Data availability of Geographic and Natural Resource Analysis (Zambia)',
    label='tab:geo_data_availability')
)
# Out:
# \begin{table}
# \caption{Data availability of Geographic and Natural Resource Analysis (Zambia)}
# \label{tab:geo_data_availability}
# \begin{tabular}{lrrrr}
# \toprule
# Series Code & Missing (\textbackslash \%) & Obs. & First year & Last year \\
# \midrule
# AG.LND.IRIG.AG.ZS & 100.00 & 0 & NaN & NaN \\
# AG.LND.AGRI.ZS & 3.10 & 63 & 1961.00 & 2023.00 \\
# ER.H2O.FWTL.ZS & 52.30 & 31 & 1992.00 & 2022.00 \\
# AG.LND.ARBL.ZS & 3.10 & 63 & 1961.00 & 2023.00 \\
# NY.GDP.COAL.RT.ZS & 21.50 & 51 & 1971.00 & 2021.00 \\
# EN.CLC.MDAT.ZS & 98.50 & 1 & 2009.00 & 2009.00 \\
# AG.LND.FRST.ZS & 47.70 & 34 & 1990.00 & 2023.00 \\
# NY.GDP.FRST.RT.ZS & 20.00 & 52 & 1970.00 & 2021.00 \\
# VC.IDP.NWDS & 80.00 & 13 & 2008.00 & 2023.00 \\
# ER.H2O.FWST.ZS & 52.30 & 31 & 1992.00 & 2022.00 \\
# NY.GDP.MINR.RT.ZS & 20.00 & 52 & 1970.00 & 2021.00 \\
# NY.GDP.NGAS.RT.ZS & 21.50 & 51 & 1971.00 & 2021.00 \\
# NY.GDP.PETR.RT.ZS & 21.50 & 51 & 1971.00 & 2021.00 \\
# ER.H2O.INTR.PC & 4.60 & 62 & 1961.00 & 2022.00 \\
# ER.H2O.INTR.K3 & 4.60 & 62 & 1961.00 & 2022.00 \\
# NY.GDP.TOTL.RT.ZS & 20.00 & 52 & 1970.00 & 2021.00 \\
# ER.GDP.FWTL.M3.KD & 52.30 & 31 & 1992.00 & 2022.00 \\
# \bottomrule
# \end{tabular}
# \end{table}

# %%
availability, fig, ax = plot_missing_heatmap(
    geo_clean,
    lookup=geo_lookup
)

fig.savefig('../figures/Zambia/geographic/geo_data_availability.png', bbox_inches='tight')

# %% [markdown]
# # Data Visualization

# %%
geo_lookup
# Out:
#           Series Code                                        Series Name
# 0   AG.LND.IRIG.AG.ZS  Agricultural irrigated land (% of total agricu...
# 1      AG.LND.AGRI.ZS                 Agricultural land (% of land area)
# 2      ER.H2O.FWTL.ZS  Annual freshwater withdrawals, total (% of int...
# 3      AG.LND.ARBL.ZS                       Arable land (% of land area)
# 4   NY.GDP.COAL.RT.ZS                              Coal rents (% of GDP)
# 5      EN.CLC.MDAT.ZS  Droughts, floods, extreme temperatures (% of p...
# 6      AG.LND.FRST.ZS                       Forest area (% of land area)
# 7   NY.GDP.FRST.RT.ZS                            Forest rents (% of GDP)
# 8         VC.IDP.NWDS  Internally displaced persons, new displacement...
# 9      ER.H2O.FWST.ZS  Level of water stress: freshwater withdrawal a...
# 10  NY.GDP.MINR.RT.ZS                           Mineral rents (% of GDP)
# 11  NY.GDP.NGAS.RT.ZS                       Natural gas rents (% of GDP)
# 12  NY.GDP.PETR.RT.ZS                               Oil rents (% of GDP)
# 13     ER.H2O.INTR.PC  Renewable internal freshwater resources per ca...
# 14     ER.H2O.INTR.K3  Renewable internal freshwater resources, total...
# 15  NY.GDP.TOTL.RT.ZS           Total natural resources rents (% of GDP)
# 16  ER.GDP.FWTL.M3.KD  Water productivity, total (constant 2015 US$ G...

# %% [markdown]
# ## Geographic and Climate Measures

# %%
# percentage of arable land
df = geo_clean.dropna(subset=['AG.LND.AGRI.ZS','AG.LND.ARBL.ZS'])
fig, ax = plt.subplots(figsize=(10, 6))

ax.plot(df['Year'], df['AG.LND.AGRI.ZS'], label= 'Agricultural Land')
ax.plot(df['Year'], df['AG.LND.ARBL.ZS'], label= 'Arable Land')

ax.set_xlabel('Year')
ax.set_ylabel('% of Land Area')
ax.legend()
ax.grid(False)

ax.set_xlim(1958, 2026)
# Out:
# (1958.0, 2026.0)

# %%
# Show range, average, and std of arable land and agricultural land by statistic table
df = geo_clean.dropna(subset=['AG.LND.AGRI.ZS','AG.LND.ARBL.ZS'])
df[['AG.LND.AGRI.ZS','AG.LND.ARBL.ZS']].describe()
# Out:
#        AG.LND.AGRI.ZS  AG.LND.ARBL.ZS
# count       63.000000       63.000000
# mean        28.972316        4.000101
# std          2.196214        0.603968
# min         25.971563        3.102006
# 25%         27.057803        3.616540
# 50%         28.336405        3.825717
# 75%         31.030146        4.079285
# max         32.067959        5.111718

# %%
print(
    make_summary_latex(
    df[['AG.LND.AGRI.ZS','AG.LND.ARBL.ZS']].describe().T,
    caption='Summary statistics of Agricultural Land and Arable Land (% of land area)',
    label='tab:land_summary')
)
# Out:
# \begin{table}
# \caption{Summary statistics of Agricultural Land and Arable Land (% of land area)}
# \label{tab:land_summary}
# \begin{tabular}{rrrrrrrr}
# \toprule
# count & mean & std & min & 25\% & 50\% & 75\% & max \\
# \midrule
# 63.00 & 28.97 & 2.20 & 25.97 & 27.06 & 28.34 & 31.03 & 32.07 \\
# 63.00 & 4.00 & 0.60 & 3.10 & 3.62 & 3.83 & 4.08 & 5.11 \\
# \bottomrule
# \end{tabular}
# \end{table}

# %%
# data on climate such as temperature, rainfall etc (long-term averages)
df = geo_clean.dropna(subset = ['EN.CLC.MDAT.ZS'])
df['EN.CLC.MDAT.ZS'] # Droughts, floods, extreme temperatures (% of population, average 1990-2009)
# Out:
# 49    4.199677
# Name: EN.CLC.MDAT.ZS, dtype: float64

# %% [markdown]
# Check more temperature and rainfall data on:
# https://climateknowledgeportal.worldbank.org/country/zambia/climate-data-historical

# %%
month_order = ['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun',
               'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec']

osc_all['Month'] = pd.Categorical(
    osc_all['Month'],
    categories=month_order,
    ordered=True
)

# %%
# Average Overall Observed Seasonal Cycle
osc_avg = (
    osc_all.groupby('Month', observed=True)[['tas', 'tasmin', 'tasmax', 'pr']]
    .mean()
    .reset_index()
)

fig, ax1 = plt.subplots(figsize=(10, 5))

ax1.bar(osc_avg['Month'], osc_avg['pr'], alpha=0.7)
ax1.set_ylabel('Precipitation (mm)', fontsize=12)
ax1.set_xlabel('Month', fontsize=12)

ax2 = ax1.twinx()
ax2.plot(osc_avg['Month'], osc_avg['tas'], marker='o')
ax2.set_ylabel('Mean Temperature (°C)', fontsize=12)

ax1.grid(False)
ax2.grid(False)

fig.savefig(
    "../figures/Zambia/geographic/avg_overall_osc.pdf",
    format="pdf",
    bbox_inches="tight")

# %%
# Recent Observed Seasonal Cycle (1991-2020)
fig, ax1 = plt.subplots(figsize=(10, 5))

ax1.bar(osc4['Month'], osc4['pr'], alpha=0.7)
ax1.set_ylabel('Precipitation (mm)', fontsize=12)
ax1.set_xlabel('Month', fontsize=12)
ax1.grid(False)

ax2 = ax1.twinx()
ax2.plot(osc4['Month'], osc4['tas'], marker='o')
ax2.set_ylabel('Mean Temperature (°C)', fontsize=12)
ax2.grid(False)

fig.savefig(
    "../figures/Zambia/geographic/recent_osc_91_20.pdf",
    format="pdf",
    bbox_inches="tight")

# %%
# period-to-period comparison: Temperature
selected_months = ['Jan', 'Jul', 'Oct']
osc_sel = osc_all[osc_all['Month'].isin(selected_months)]

fig, ax = plt.subplots(figsize=(10, 5))

for month in selected_months:
    temp_data = osc_sel[osc_sel['Month'] == month]
    ax.plot(temp_data['Period'], temp_data['tas'], marker='o', label=month)

ax.set_xlabel('Period')
ax.set_ylabel('Mean Temperature (°C)')
ax.grid(False)

ax.legend(title='Month')
plt.tight_layout()
plt.show()

# %%
pivot_temp = osc_all.pivot(index='Month', columns='Period', values='tas')

month_order = ['Jan','Feb','Mar','Apr','May','Jun',
               'Jul','Aug','Sep','Oct','Nov','Dec']

pivot_temp = pivot_temp.loc[month_order]

pivot_temp['Difference (1901-1930 with 1991-2020)'] = (
    pivot_temp['1991-2020'] - pivot_temp['1901-1930']
)
pivot_temp
# Out:
# Period  1901-1930  1931-1960  1961-1990  1991-2020  \
# Month
# Jan         22.97      22.91      22.83      23.33
# Feb         22.97      22.96      22.89      23.50
# Mar         22.79      22.83      22.84      23.40
# Apr         21.88      22.02      21.86      22.26
# May         19.51      19.72      19.53      20.23
# Jun         17.50      17.35      17.31      18.12
# Jul         16.92      17.10      17.07      17.66
# Aug         19.16      19.32      19.43      20.16
# Sep         22.66      22.69      22.85      23.43
# Oct         24.82      24.95      24.66      25.35
# Nov         24.44      24.25      24.19      25.01
# Dec         23.33      23.13      23.08      23.78
#
# Period  Difference (1901-1930 with 1991-2020)
# Month
# Jan                                      0.36
# Feb                                      0.53
# Mar                                      0.61
# Apr                                      0.38
# May                                      0.72
# Jun                                      0.62
# Jul                                      0.74
# Aug                                      1.00
# Sep                                      0.77
# Oct                                      0.53
# Nov                                      0.57
# Dec                                      0.45

# %%
pivot_pr = osc_all.pivot(index='Month', columns='Period', values='pr')
pivot_pr = pivot_pr.loc[month_order]

pivot_pr['Difference (1901-1930 with 1991-2020)'] = (
    pivot_pr['1991-2020'] - pivot_pr['1901-1930']
)
pivot_pr
# Out:
# Period  1901-1930  1931-1960  1961-1990  1991-2020  \
# Month
# Jan        225.03     235.98     231.36     235.23
# Feb        205.38     216.55     205.61     197.02
# Mar        165.64     164.82     159.83     161.99
# Apr         38.98      40.70      49.95      42.84
# May          6.05       5.56       6.09       5.72
# Jun          0.40       0.53       0.59       0.49
# Jul          0.10       0.08       0.13       0.18
# Aug          0.14       0.22       0.26       0.26
# Sep          2.47       1.96       3.03       2.64
# Oct         22.82      22.80      28.20      23.11
# Nov        100.51     112.13     112.02     109.86
# Dec        209.51     218.71     223.42     207.92
#
# Period  Difference (1901-1930 with 1991-2020)
# Month
# Jan                                     10.20
# Feb                                     -8.36
# Mar                                     -3.65
# Apr                                      3.86
# May                                     -0.33
# Jun                                      0.09
# Jul                                      0.08
# Aug                                      0.12
# Sep                                      0.17
# Oct                                      0.29
# Nov                                      9.35
# Dec                                     -1.59

# %%
month_order = ['Jan','Feb','Mar','Apr','May','Jun',
               'Jul','Aug','Sep','Oct','Nov','Dec']

# Precipitation
pivot_pr = osc_all.pivot(index='Month', columns='Period', values='pr')
pivot_pr = pivot_pr.loc[month_order]
pivot_pr['diff_pr'] = pivot_pr['1991-2020'] - pivot_pr['1901-1930']

# Temperature
pivot_temp = osc_all.pivot(index='Month', columns='Period', values='tas')
pivot_temp = pivot_temp.loc[month_order]
pivot_temp['diff_tas'] = pivot_temp['1991-2020'] - pivot_temp['1901-1930']

# %%
# Monthly Precipitation Difference: 1991–2020 vs 1901–1930

fig, ax1 = plt.subplots(figsize=(10, 5))

ax1.bar(pivot_pr.index, pivot_pr['diff_pr'], alpha=0.7)
ax1.axhline(0, linewidth=1)
ax1.set_xlabel('Month', fontsize=12)
ax1.set_ylabel('Precipitation Difference (mm)', fontsize=12)
ax1.grid(False)

ax2 = ax1.twinx()
ax2.plot(pivot_temp.index, pivot_temp['diff_tas'], marker='o')
ax2.axhline(0, linewidth=1)
ax2.set_ylabel('Temperature Difference (°C)', fontsize=12)
ax2.grid(False)

fig.savefig(
    "../figures/Zambia/geographic/osc_diff.pdf",
    format="pdf",
    bbox_inches="tight")

# %% [markdown]
# ## Natural Resource Measures

# %%
# oil rents as % of GDP NY.GDP.PETR.RT.ZS
df = geo_clean.dropna(subset=['NY.GDP.PETR.RT.ZS'])
df['NY.GDP.PETR.RT.ZS'].describe()
# Out:
# count    51.0
# mean      0.0
# std       0.0
# min       0.0
# 25%       0.0
# 50%       0.0
# 75%       0.0
# max       0.0
# Name: NY.GDP.PETR.RT.ZS, dtype: float64

# %%
# natural gas rents as % of GDP NY.GDP.NGAS.RT.ZS
df = geo_clean.dropna(subset=['NY.GDP.NGAS.RT.ZS'])
df['NY.GDP.NGAS.RT.ZS'].describe()
# Out:
# count    51.0
# mean      0.0
# std       0.0
# min       0.0
# 25%       0.0
# 50%       0.0
# 75%       0.0
# max       0.0
# Name: NY.GDP.NGAS.RT.ZS, dtype: float64

# %%
# Mineral rents (% of GDP) NY.GDP.MINR.RT.ZS
df = geo_clean.dropna(subset=['NY.GDP.MINR.RT.ZS'])
df['NY.GDP.MINR.RT.ZS'].describe()
# Out:
# count    52.000000
# mean      8.564927
# std       9.193784
# min       0.003760
# 25%       0.618390
# 50%       6.011558
# 75%      13.418640
# max      36.853111
# Name: NY.GDP.MINR.RT.ZS, dtype: float64

# %%
df = geo_clean.dropna(subset=['NY.GDP.MINR.RT.ZS'])
fig, ax = plt.subplots(figsize=(10, 5))
ax.plot(df['Year'], df['NY.GDP.MINR.RT.ZS'], marker='o')

ax.set_xlabel('Year', fontsize=12)
ax.set_ylabel('Mineral Rents (% of GDP)', fontsize=12)

ax.set_xlim(1958, 2026)
ax.grid(False)

fig.savefig(
    "../figures/Zambia/geographic/mineral_rents.pdf",
    format="pdf",
    bbox_inches="tight")

# %%
# total natural resources rents (% of GDP) NY.GDP.TOTL.RT.ZS
df = geo_clean.dropna(subset=['NY.GDP.TOTL.RT.ZS'])
df['NY.GDP.TOTL.RT.ZS'].describe()
# Out:
# count    52.000000
# mean     14.047598
# std       8.048952
# min       5.088038
# 25%       7.781853
# 50%      12.331205
# 75%      17.176481
# max      38.705206
# Name: NY.GDP.TOTL.RT.ZS, dtype: float64

# %%
df = geo_clean.dropna(subset=['NY.GDP.TOTL.RT.ZS'])
fig, ax = plt.subplots(figsize=(10, 5))
ax.plot(df['Year'], df['NY.GDP.TOTL.RT.ZS'], marker='o')

ax.set_xlabel('Year', fontsize=12)
ax.set_ylabel('Total Natural Resources Rents (% of GDP)', fontsize=12)

ax.set_xlim(1958, 2026)
ax.grid(False)

fig.savefig(
    "../figures/Zambia/geographic/total_natural_resource_rents.pdf",
    format="pdf",
    bbox_inches="tight")
