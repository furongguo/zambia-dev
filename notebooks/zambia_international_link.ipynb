# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import statsmodels.api as sm
from WBUtiles.WBClean import clean_wb_wide
from WBUtiles.WBSummary import summary_wb, plot_missing_heatmap
from WBUtiles.WBLatex import make_lookup_latex, make_summary_latex

sns.set_theme(
    style="whitegrid",     # clean academic look
    context="paper",       # scales text for papers
    font_scale=1.1
)

# %% [markdown]
# # Data Cleaning

# %% [markdown]
# # Check Data Availability

# %% [markdown]
# # Data Visualization

# %% [markdown]
# ## International Trade

# %%
# merchandise exports (as percentage of GDP)

# %%
# merchandise imports (as percentage of GDP)

# %%
# structure of merchandise exports: food commodities (SITC
# section 0, 1, 2, 4), fuels (SITC section 3), machinery (SITC
# section 7), other manufactures (SITC section 5, 6, 8, 9)

# %%
# structure of merchandise imports: food commodities (SITC
# section 0, 1, 2, 4), fuels (SITC section 3), machinery (SITC
# section 7), other manufactures (SITC section 5, 6, 8, 9)

# %% [markdown]
# ## International Investment

# %%
# Inbound FDI, net (percentage of GDP)

# %% [markdown]
# ## Private International Transfers

# %%
# Remittances (percentage of GDP)

# %% [markdown]
# ## Official International Transfers

# %%
# official development assistance: receipts per capita (in dollars)

# %%
# official development assistance: total receipts (percentage of GDP)
